# %%
# https://towardsdatascience.com/basic-time-series-manipulation-with-pandas-4432afee64ea

import pandas as pd
from datetime import datetime
import numpy as np
date_rng = pd.date_range(start='1/1/2018', end='1/08/2018', freq='H')
date_rng
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00', '2018-01-01 03:00:00',
#                '2018-01-01 04:00:00', '2018-01-01 05:00:00',
#                '2018-01-01 06:00:00', '2018-01-01 07:00:00',
#                '2018-01-01 08:00:00', '2018-01-01 09:00:00',
#                ...
#                '2018-01-07 15:00:00', '2018-01-07 16:00:00',
#                '2018-01-07 17:00:00', '2018-01-07 18:00:00',
#                '2018-01-07 19:00:00', '2018-01-07 20:00:00',
#                '2018-01-07 21:00:00', '2018-01-07 22:00:00',
#                '2018-01-07 23:00:00', '2018-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq='H')

# %%
type(date_rng[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.DataFrame(date_rng, columns=['date'])
# df['date']
df['data'] = np.random.randint(0,100,size=(len(date_rng)))
df.head(15)
# Out:
#                   date  data
# 0  2018-01-01 00:00:00     1
# 1  2018-01-01 01:00:00    74
# 2  2018-01-01 02:00:00     8
# 3  2018-01-01 03:00:00    35
# 4  2018-01-01 04:00:00    55
# 5  2018-01-01 05:00:00    31
# 6  2018-01-01 06:00:00    71
# 7  2018-01-01 07:00:00    13
# 8  2018-01-01 08:00:00    73
# 9  2018-01-01 09:00:00    16
# 10 2018-01-01 10:00:00     2
# 11 2018-01-01 11:00:00    95
# 12 2018-01-01 12:00:00    75
# 13 2018-01-01 13:00:00    59
# 14 2018-01-01 14:00:00    38

# %%
df['datetime'] = pd.to_datetime(df['date'])
df = df.set_index('datetime')
df.drop(['date'], axis=1, inplace=True)
df.head()
# Out:
#                      data
# datetime
# 2018-01-01 00:00:00     7
# 2018-01-01 01:00:00    78
# 2018-01-01 02:00:00    70
# 2018-01-01 03:00:00     7
# 2018-01-01 04:00:00    54

# %%
string_date_rng = [str(x) for x in date_rng]
string_date_rng
# Out:
# ['2018-01-01 00:00:00',
#  '2018-01-01 01:00:00',
#  '2018-01-01 02:00:00',
#  '2018-01-01 03:00:00',
#  '2018-01-01 04:00:00',
#  '2018-01-01 05:00:00',
#  '2018-01-01 06:00:00',
#  '2018-01-01 07:00:00',
#  '2018-01-01 08:00:00',
#  '2018-01-01 09:00:00',
#  '2018-01-01 10:00:00',
#  '2018-01-01 11:00:00',
#  '2018-01-01 12:00:00',
#  '2018-01-01 13:00:00',
#  '2018-01-01 14:00:00',
#  '2018-01-01 15:00:00',
#  '2018-01-01 16:00:00',
#  '2018-01-01 17:00:00',
#  '2018-01-01 18:00:00',
#  '2018-01-01 19:00:00',
#  '2018-01-01 20:00:00',
#  '2018-01-01 21:00:00',
#  '2018-01-01 22:00:00',
#  '2018-01-01 23:00:00',
#  '2018-01-02 00:00:00',
#  '2018-01-02 01:00:00',
#  '2018-01-02 02:00:00',
#  '2018-01-02 03:00:00',
#  '2018-01-02 04:00:00',
#  '2018-01-02 05:00:00',
#  '2018-01-02 06:00:00',
#  '2018-01-02 07:00:00',
#  '2018-01-02 08:00:00',
#  '2018-01-02 09:00:00',
#  '2018-01-02 10:00:00',
#  '2018-01-02 11:00:00',
#  '2018-01-02 12:00:00',
#  '2018-01-02 13:00:00',
#  '2018-01-02 14:00:00',
#  '2018-01-02 15:00:00',
#  '2018-01-02 16:00:00',
#  '2018-01-02 17:00:00',
#  '2018-01-02 18:00:00',
#  '2018-01-02 19:00:00',
#  '2018-01-02 20:00:00',
#  '2018-01-02 21:00:00',
#  '2018-01-02 22:00:00',
#  '2018-01-02 23:00:00',
#  '2018-01-03 00:00:00',
#  '2018-01-03 01:00:00',
#  '2018-01-03 02:00:00',
#  '2018-01-03 03:00:00',
#  '2018-01-03 04:00:00',
#  '2018-01-03 05:00:00',
#  '2018-01-03 06:00:00',
#  '2018-01-03 07:00:00',
#  '2018-01-03 08:00:00',
#  '2018-01-03 09:00:00',
#  '2018-01-03 10:00:00',
#  '2018-01-03 11:00:00',
#  '2018-01-03 12:00:00',
#  '2018-01-03 13:00:00',
#  '2018-01-03 14:00:00',
#  '2018-01-03 15:00:00',
#  '2018-01-03 16:00:00',
#  '2018-01-03 17:00:00',
#  '2018-01-03 18:00:00',
#  '2018-01-03 19:00:00',
#  '2018-01-03 20:00:00',
#  '2018-01-03 21:00:00',
#  '2018-01-03 22:00:00',
#  '2018-01-03 23:00:00',
#  '2018-01-04 00:00:00',
#  '2018-01-04 01:00:00',
#  '2018-01-04 02:00:00',
#  '2018-01-04 03:00:00',
#  '2018-01-04 04:00:00',
#  '2018-01-04 05:00:00',
#  '2018-01-04 06:00:00',
#  '2018-01-04 07:00:00',
#  '2018-01-04 08:00:00',
#  '2018-01-04 09:00:00',
#  '2018-01-04 10:00:00',
#  '2018-01-04 11:00:00',
#  '2018-01-04 12:00:00',
#  '2018-01-04 13:00:00',
#  '2018-01-04 14:00:00',
#  '2018-01-04 15:00:00',
#  '2018-01-04 16:00:00',
#  '2018-01-04 17:00:00',
#  '2018-01-04 18:00:00',
#  '2018-01-04 19:00:00',
#  '2018-01-04 20:00:00',
#  '2018-01-04 21:00:00',
#  '2018-01-04 22:00:00',
#  '2018-01-04 23:00:00',
#  '2018-01-05 00:00:00',
#  '2018-01-05 01:00:00',
#  '2018-01-05 02:00:00',
#  '2018-01-05 03:00:00',
#  '2018-01-05 04:00:00',
#  '2018-01-05 05:00:00',
#  '2018-01-05 06:00:00',
#  '2018-01-05 07:00:00',
#  '2018-01-05 08:00:00',
#  '2018-01-05 09:00:00',
#  '2018-01-05 10:00:00',
#  '2018-01-05 11:00:00',
#  '2018-01-05 12:00:00',
#  '2018-01-05 13:00:00',
#  '2018-01-05 14:00:00',
#  '2018-01-05 15:00:00',
#  '2018-01-05 16:00:00',
#  '2018-01-05 17:00:00',
#  '2018-01-05 18:00:00',
#  '2018-01-05 19:00:00',
#  '2018-01-05 20:00:00',
#  '2018-01-05 21:00:00',
#  '2018-01-05 22:00:00',
#  '2018-01-05 23:00:00',
#  '2018-01-06 00:00:00',
#  '2018-01-06 01:00:00',
#  '2018-01-06 02:00:00',
#  '2018-01-06 03:00:00',
#  '2018-01-06 04:00:00',
#  '2018-01-06 05:00:00',
#  '2018-01-06 06:00:00',
#  '2018-01-06 07:00:00',
#  '2018-01-06 08:00:00',
#  '2018-01-06 09:00:00',
#  '2018-01-06 10:00:00',
#  '2018-01-06 11:00:00',
#  '2018-01-06 12:00:00',
#  '2018-01-06 13:00:00',
#  '2018-01-06 14:00:00',
#  '2018-01-06 15:00:00',
#  '2018-01-06 16:00:00',
#  '2018-01-06 17:00:00',
#  '2018-01-06 18:00:00',
#  '2018-01-06 19:00:00',
#  '2018-01-06 20:00:00',
#  '2018-01-06 21:00:00',
#  '2018-01-06 22:00:00',
#  '2018-01-06 23:00:00',
#  '2018-01-07 00:00:00',
#  '2018-01-07 01:00:00',
#  '2018-01-07 02:00:00',
#  '2018-01-07 03:00:00',
#  '2018-01-07 04:00:00',
#  '2018-01-07 05:00:00',
#  '2018-01-07 06:00:00',
#  '2018-01-07 07:00:00',
#  '2018-01-07 08:00:00',
#  '2018-01-07 09:00:00',
#  '2018-01-07 10:00:00',
#  '2018-01-07 11:00:00',
#  '2018-01-07 12:00:00',
#  '2018-01-07 13:00:00',
#  '2018-01-07 14:00:00',
#  '2018-01-07 15:00:00',
#  '2018-01-07 16:00:00',
#  '2018-01-07 17:00:00',
#  '2018-01-07 18:00:00',
#  '2018-01-07 19:00:00',
#  '2018-01-07 20:00:00',
#  '2018-01-07 21:00:00',
#  '2018-01-07 22:00:00',
#  '2018-01-07 23:00:00',
#  '2018-01-08 00:00:00']

# %%
timestamp_date_rng = pd.to_datetime(string_date_rng, infer_datetime_format=True)
timestamp_date_rng
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00', '2018-01-01 03:00:00',
#                '2018-01-01 04:00:00', '2018-01-01 05:00:00',
#                '2018-01-01 06:00:00', '2018-01-01 07:00:00',
#                '2018-01-01 08:00:00', '2018-01-01 09:00:00',
#                ...
#                '2018-01-07 15:00:00', '2018-01-07 16:00:00',
#                '2018-01-07 17:00:00', '2018-01-07 18:00:00',
#                '2018-01-07 19:00:00', '2018-01-07 20:00:00',
#                '2018-01-07 21:00:00', '2018-01-07 22:00:00',
#                '2018-01-07 23:00:00', '2018-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq=None)

# %%
string_date_rng_2 = ['June-01-2018', 'June-02-2018', 'June-03-2018']
timestamp_date_rng_2 = [datetime.strptime(x,'%B-%d-%Y') for x in string_date_rng_2]
timestamp_date_rng_2
# Out:
# [datetime.datetime(2018, 6, 1, 0, 0),
#  datetime.datetime(2018, 6, 2, 0, 0),
#  datetime.datetime(2018, 6, 3, 0, 0)]

# %%
df2 = pd.DataFrame(timestamp_date_rng_2, columns=['date'])
df2
# Out:
#         date
# 0 2018-06-01
# 1 2018-06-02
# 2 2018-06-03
