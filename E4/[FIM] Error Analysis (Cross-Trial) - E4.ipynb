# %%
'''
Trial Descriptions
Trial 1 - weight: 1/d
Trial 2 - Normalised
Trial 3 - Feature Engineered + Normalised
Trial 4 - weight: 1 / (d^2)
Trial 5 - weight : Dudani weighting
Trial 6 - T4 parameters, integer output
'''
import pandas as pd
import matplotlib.pyplot as plt


error_E4T1 = pd.read_csv('E4_ErrSummary_T1.csv')
error_E4T2 = pd.read_csv('E4_ErrSummary_T2.csv')
error_E4T3 = pd.read_csv('E4_ErrSummary_T3.csv')
error_E4T4 = pd.read_csv('E4_ErrSummary_T4.csv')
error_E4T5 = pd.read_csv('E4_ErrSummary_T5.csv')
error_E4T6 = pd.read_csv('E4_ErrSummary_T6.csv')

print("Trial 1:")
print(error_E4T1)
print("Trial 2:")
print(error_E4T2)
print("Trial 3:")
print(error_E4T3)
print("Trial 4:")
print(error_E4T4)
print("Trial 5:")
print(error_E4T5)
print("Trial 6:")
print(error_E4T6)
# Out:
# Trial 1:
#    Algorithm  Mean Error  Median Error  0.75 Quantile Error  Max Error
# 0     knn_k1    1.396071      0.000000         0.000000e+00  18.973666
# 1    knn_k15    2.787427      2.154066         4.472136e+00  17.088007
# 2    knn_k31    3.296385      2.791395         4.873424e+00  15.350230
# 3    knn_k63    3.902022      3.462792         5.323971e+00  15.061476
# 4   dwknn_k1    1.396071      0.000000         8.881784e-16  18.973666
# 5  dwknn_k15    2.253311      1.155862         3.524047e+00  16.959002
# 6  dwknn_k31    2.571725      1.666112         3.893213e+00  16.203461
# 7  dwknn_k63    2.963554      2.267921         4.301332e+00  16.186615
# Trial 2:
#    Algorithm  Mean Error  Median Error  0.75 Quantile Error  Max Error
# 0     knn_k1    1.465652      0.000000         0.000000e+00  18.973666
# 1    knn_k15    2.963601      2.400000         4.740940e+00  17.088007
# 2    knn_k31    3.456090      2.909670         5.047124e+00  15.994406
# ...

# %% [markdown]
# # Mean Error Analysis

# %%
plt.figure(figsize = (10,10))
plt.plot(error_E4T1['Algorithm'][:4], error_E4T1['Mean Error'][:4], label = "E4T1")
plt.plot(error_E4T2['Algorithm'][:4], error_E4T2['Mean Error'][:4], label = "E4T2")
plt.plot(error_E4T3['Algorithm'][:4], error_E4T3['Mean Error'][:4], label = "E4T3")
plt.plot(error_E4T4['Algorithm'][:4], error_E4T4['Mean Error'][:4], label = "E4T4")
plt.plot(error_E4T5['Algorithm'][:4], error_E4T5['Mean Error'][:4], label = "E4T5")
plt.plot(error_E4T6['Algorithm'][:4], error_E4T6['Mean Error'][:4], label = "E4T6")


plt.legend(loc='best', fontsize=20)
plt.show()

plt.figure(figsize = (10,10))
plt.plot(error_E4T1['Algorithm'][4:], error_E4T1['Mean Error'][4:], label = "E4T1")
plt.plot(error_E4T2['Algorithm'][4:], error_E4T2['Mean Error'][4:], label = "E4T2")
plt.plot(error_E4T3['Algorithm'][4:], error_E4T3['Mean Error'][4:], label = "E4T3")
plt.plot(error_E4T4['Algorithm'][4:], error_E4T4['Mean Error'][4:], label = "E4T4")
plt.plot(error_E4T5['Algorithm'][4:], error_E4T5['Mean Error'][4:], label = "E4T5")
plt.plot(error_E4T6['Algorithm'][4:], error_E4T6['Mean Error'][4:], label = "E4T6")


plt.legend(loc='best', fontsize=20)
plt.show()

# %% [markdown]
# # Median Error Analysis

# %%
plt.clf()
plt.figure(figsize = (10,10))
plt.plot(error_E4T1['Algorithm'], error_E4T1['Median Error'], label = "E4T1")
plt.plot(error_E4T2['Algorithm'], error_E4T2['Median Error'], label = "E4T2")
plt.plot(error_E4T3['Algorithm'], error_E4T3['Median Error'], label = "E4T3")
plt.plot(error_E4T4['Algorithm'], error_E4T4['Median Error'], label = "E4T4")
plt.plot(error_E4T5['Algorithm'], error_E4T5['Median Error'], label = "E4T5")
plt.plot(error_E4T6['Algorithm'], error_E4T6['Median Error'], label = "E4T6")
plt.legend(loc='best', fontsize=20)
plt.show()

# %% [markdown]
# # 0.75 Quantile Error

# %%
plt.figure(figsize = (10,10))
plt.plot(error_E4T1['Algorithm'], error_E4T1['0.75 Quantile Error'], label = "E4T1")
plt.plot(error_E4T2['Algorithm'], error_E4T2['0.75 Quantile Error'], label = "E4T2")
plt.plot(error_E4T3['Algorithm'], error_E4T3['0.75 Quantile Error'], label = "E4T3")
plt.plot(error_E4T4['Algorithm'], error_E4T4['0.75 Quantile Error'], label = "E4T4")
plt.plot(error_E4T5['Algorithm'], error_E4T5['0.75 Quantile Error'], label = "E4T5")
plt.plot(error_E4T6['Algorithm'], error_E4T6['0.75 Quantile Error'], label = "E4T6")

plt.legend(loc='best', fontsize=20)
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.plot(error_E4T1['Algorithm'], error_E4T1['Max Error'], label = "E4T1")
plt.plot(error_E4T2['Algorithm'], error_E4T2['Max Error'], label = "E4T2")
plt.plot(error_E4T3['Algorithm'], error_E4T3['Max Error'], label = "E4T3")
plt.plot(error_E4T4['Algorithm'], error_E4T4['Max Error'], label = "E4T4")
plt.plot(error_E4T5['Algorithm'], error_E4T5['Max Error'], label = "E4T5")
plt.plot(error_E4T6['Algorithm'], error_E4T6['Max Error'], label = "E4T6")
plt.legend(loc='best', fontsize=20)
plt.show()
